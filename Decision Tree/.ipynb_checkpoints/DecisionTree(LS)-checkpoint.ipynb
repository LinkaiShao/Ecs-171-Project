# %%
import pandas as pd

# Specify the correct file paths
math_path = "C:/Users/linka/Downloads/student+performance/student/student-mat.csv"
por_path = "C:/Users/linka/Downloads/student+performance/student/student-por.csv"

# Load the datasets with the correct delimiter
df_math = pd.read_csv(math_path, delimiter=';')
df_por = pd.read_csv(por_path, delimiter=';')

# Check the first few rows to confirm the data is loaded correctly
print(df_math.head())
print(df_por.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
# Math dataset
X_math = df_math.drop('G3', axis=1)  
y_math = df_math['G3']               

# Portuguese dataset
X_por = df_por.drop('G3', axis=1)
y_por = df_por['G3']
X_math_encoded = pd.get_dummies(X_math, drop_first=True)


X_por_encoded = pd.get_dummies(X_por, drop_first=True)


print(X_math_encoded.head())
print(X_por_encoded.head())
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  ...  guardian_mother  guardian_other  schoolsup_yes  famsup_yes  \
# 0     1  ...             True           False           True       False
# 1     1  ...            False           False          False        True
# 2     2  ...             True           False           True       False
# 3     1  ...             True           False          False        True
# 4     1  ...            False           False          False        True
#
#    paid_yes  activities_yes  nursery_yes  higher_yes  internet_yes  \
# 0     False           False         True        True         False
# 1     False           False        False        True          True
# 2      True           False         True        True          True
# 3      True            True         True        True          True
# 4      True           False         True        True         False
#
#    romantic_yes
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#
# [5 rows x 41 columns]
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         0       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  ...  guardian_mother  guardian_other  schoolsup_yes  famsup_yes  \
# 0     1  ...             True           False           True       False
# 1     1  ...            False           False          False        True
# 2     2  ...             True           False           True       False
# 3     1  ...             True           False          False        True
# 4     1  ...            False           False          False        True
#
#    paid_yes  activities_yes  nursery_yes  higher_yes  internet_yes  \
# 0     False           False         True        True         False
# 1     False           False        False        True          True
# 2     False           False         True        True          True
# 3     False            True         True        True          True
# 4     False           False         True        True         False
#
#    romantic_yes
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#
# [5 rows x 41 columns]

# %%
from sklearn.model_selection import train_test_split

# Math dataset split
X_train_math, X_test_math, y_train_math, y_test_math = train_test_split(X_math_encoded, y_math, test_size=0.2, random_state=42)

# Portuguese dataset split
X_train_por, X_test_por, y_train_por, y_test_por = train_test_split(X_por_encoded, y_por, test_size=0.2, random_state=42)

# %% [markdown]
# ## Train Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Select only the specified features for Math dataset
selected_features = ['failures', 'Medu', 'higher_yes', 'age', 'Fedu', 'goout', 'romantic_yes', 'traveltime']
X_train_math_selected = X_train_math[selected_features]
X_test_math_selected = X_test_math[selected_features]
X_train_por_selected = X_train_por[selected_features]
X_test_por_selected = X_test_por[selected_features]

# %%
# Math dataset
model_math = DecisionTreeRegressor(max_depth=5, random_state=42)  # Adjust max_depth as needed
model_math.fit(X_train_math_selected, y_train_math)

# Portuguese dataset
model_por = DecisionTreeRegressor(max_depth=5, random_state=42)
model_por.fit(X_train_por_selected, y_train_por)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=42)

# %%
from sklearn.metrics import mean_squared_error, r2_score

def evaluate_model(model, X_test, y_test, dataset_name="Dataset"):
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"\n{dataset_name}")
    print(f"Mean Squared Error: {mse:.2f}")
    print(f"R² Score: {r2:.2f}")
    return {"Mean Squared Error": mse, "R² Score": r2}

# %%
# For the Math dataset
results_math = evaluate_model(model_math, X_test_math_selected, y_test_math, dataset_name="Math Dataset")

# For the Portuguese dataset
results_por = evaluate_model(model_por, X_test_por_selected, y_test_por, dataset_name="Portuguese Dataset")
# Out:
# Math Dataset
# Mean Squared Error: 23.88
# R² Score: -0.16
#
# Portuguese Dataset
# Mean Squared Error: 8.60
# R² Score: 0.12

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Visualize Math decision tree
plt.figure(figsize=(20,10))
plot_tree(model_math, feature_names=X_math_encoded.columns, filled=True)
plt.title("Decision Tree for Math Dataset")
plt.show()

# Visualize Portuguese decision tree
plt.figure(figsize=(20,10))
plot_tree(model_por, feature_names=X_por_encoded.columns, filled=True)
plt.title("Decision Tree for Portuguese Dataset")
plt.show()

# %%
from sklearn.tree import export_text
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Simplified tree visualization
def simplified_tree_plot(model, feature_names, title="Decision Tree"):
    plt.figure(figsize=(12, 8))
    plot_tree(
        model,
        feature_names=feature_names,  # Show feature names
        filled=True,                  # Fill with color
        rounded=True,                 # Rounded boxes for better aesthetics
        max_depth=4,                  # Control the depth for readability
        proportion=False              # No percentages needed
    )
    plt.title(title)
    plt.show()

# %%
from sklearn.tree import export_text

# For Math Dataset
print("Decision Tree - Math Dataset")
tree_math_text = export_text(model_math, feature_names=X_train_math_selected.columns.tolist())
print(tree_math_text)

# For Portuguese Dataset
print("\nDecision Tree - Portuguese Dataset")
tree_por_text = export_text(model_por, feature_names=X_train_por_selected.columns.tolist())
print(tree_por_text)
# Out:
# Decision Tree - Math Dataset
# |--- failures <= 0.50
# |   |--- higher_yes <= 0.50
# |   |   |--- Fedu <= 3.50
# |   |   |   |--- goout <= 4.00
# |   |   |   |   |--- age <= 18.50
# |   |   |   |   |   |--- value: [9.50]
# |   |   |   |   |--- age >  18.50
# |   |   |   |   |   |--- value: [13.00]
# |   |   |   |--- goout >  4.00
# |   |   |   |   |--- traveltime <= 1.50
# |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |--- traveltime >  1.50
# |   |   |   |   |   |--- value: [0.00]
# |   |   |--- Fedu >  3.50
# |   |   |   |--- value: [0.00]
# |   |--- higher_yes >  0.50
# |   |   |--- goout <= 2.50
# |   |   |   |--- Medu <= 2.50
# |   |   |   |   |--- Medu <= 1.50
# |   |   |   |   |   |--- value: [12.89]
# |   |   |   |   |--- Medu >  1.50
# |   |   |   |   |   |--- value: [10.62]
# |   |   |   |--- Medu >  2.50
# |   |   |   |   |--- Fedu <= 1.50
# |   |   |   |   |   |--- value: [16.33]
# |   |   |   |   |--- Fedu >  1.50
# |   |   |   |   |   |--- value: [12.64]
# |   |   |--- goout >  2.50
# |   |   |   |--- Fedu <= 1.50
# |   |   |   |   |--- age <= 15.50
# |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |--- age >  15.50
# |   |   |   |   |   |--- value: [9.55]
# |   |   |   |--- Fedu >  1.50
# |   |   |   |   |--- traveltime <= 3.50
# |   |   |   |   |   |--- value: [11.30]
# |   |   |   |   |--- traveltime >  3.50
# |   |   |   |   |   |--- value: [5.00]
# |--- failures >  0.50
# |   |--- failures <= 1.50
# |   |   |--- goout <= 1.50
# |   |   |   |--- value: [0.00]
# |   |   |--- goout >  1.50
# |   |   |   |--- Medu <= 1.50
# |   |   |   |   |--- goout <= 3.50
# |   |   |   |   |   |--- value: [8.50]
# |   |   |   |   |--- goout >  3.50
# |   |   |   |   |   |--- value: [4.67]
# |   |   |   |--- Medu >  1.50
# |   |   |   |   |--- age <= 17.50
# |   |   |   |   |   |--- value: [11.15]
# |   |   |   |   |--- age >  17.50
# |   |   |   |   |   |--- value: [8.41]
# |   |--- failures >  1.50
# |   |   |--- age <= 18.50
# |   |   |   |--- age <= 15.50
# |   |   |   |   |--- Fedu <= 1.50
# |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |--- Fedu >  1.50
# |   |   |   |   |   |--- value: [5.00]
# |   |   |   |--- age >  15.50
# |   |   |   |   |--- traveltime <= 3.50
# |   |   |   |   |   |--- value: [1.38]
# |   |   |   |   |--- traveltime >  3.50
# |   |   |   |   |   |--- value: [7.00]
# |   |   |--- age >  18.50
# |   |   |   |--- failures <= 2.50
# |   |   |   |   |--- romantic_yes <= 0.50
# |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |--- romantic_yes >  0.50
# |   |   |   |   |   |--- value: [14.00]
# |   |   |   |--- failures >  2.50
# |   |   |   |   |--- Fedu <= 1.50
# |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |--- Fedu >  1.50
# |   |   |   |   |   |--- value: [0.00]
#
#
# Decision Tree - Portuguese Dataset
# |--- failures <= 0.50
# |   |--- higher_yes <= 0.50
# |   |   |--- Fedu <= 3.50
# |   |   |   |--- goout <= 3.50
# |   |   |   |   |--- romantic_yes <= 0.50
# |   |   |   |   |   |--- value: [12.00]
# |   |   |   |   |--- romantic_yes >  0.50
# |   |   |   |   |   |--- value: [10.29]
# |   |   |   |--- goout >  3.50
# |   |   |   |   |--- Fedu <= 2.50
# |   |   |   |   |   |--- value: [9.61]
# |   |   |   |   |--- Fedu >  2.50
# |   |   |   |   |   |--- value: [13.00]
# |   |   |--- Fedu >  3.50
# |   |   |   |--- goout <= 3.50
# |   |   |   |   |--- value: [8.00]
# |   |   |   |--- goout >  3.50
# |   |   |   |   |--- value: [6.00]
# |   |--- higher_yes >  0.50
# |   |   |--- Fedu <= 1.50
# |   |   |   |--- goout <= 4.50
# |   |   |   |   |--- Fedu <= 0.50
# |   |   |   |   |   |--- value: [13.67]
# |   |   |   |   |--- Fedu >  0.50
# |   |   |   |   |   |--- value: [11.68]
# |   |   |   |--- goout >  4.50
# |   |   |   |   |--- age <= 17.50
# |   |   |   |   |   |--- value: [10.14]
# |   |   |   |   |--- age >  17.50
# |   |   |   |   |   |--- value: [13.00]
# |   |   |--- Fedu >  1.50
# |   |   |   |--- traveltime <= 2.50
# |   |   |   |   |--- age <= 16.50
# |   |   |   |   |   |--- value: [12.72]
# |   |   |   |   |--- age >  16.50
# |   |   |   |   |   |--- value: [13.46]
# |   |   |   |--- traveltime >  2.50
# |   |   |   |   |--- Fedu <= 3.50
# |   |   |   |   |   |--- value: [12.33]
# |   |   |   |   |--- Fedu >  3.50
# |   |   |   |   |   |--- value: [8.83]
# |--- failures >  0.50
# |   |--- higher_yes <= 0.50
# |   |   |--- goout <= 3.50
# |   |   |   |--- goout <= 1.50
# |   |   |   |   |--- age <= 18.50
# |   |   |   |   |   |--- value: [3.50]
# |   |   |   |   |--- age >  18.50
# |   |   |   |   |   |--- value: [9.00]
# |   |   |   |--- goout >  1.50
# |   |   |   |   |--- Medu <= 1.50
# |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |--- Medu >  1.50
# |   |   |   |   |   |--- value: [9.00]
# |   |   |--- goout >  3.50
# |   |   |   |--- traveltime <= 1.50
# |   |   |   |   |--- Fedu <= 2.50
# |   |   |   |   |   |--- value: [6.25]
# |   |   |   |   |--- Fedu >  2.50
# |   |   |   |   |   |--- value: [9.00]
# |   |   |   |--- traveltime >  1.50
# |   |   |   |   |--- traveltime <= 2.50
# |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |--- traveltime >  2.50
# |   |   |   |   |   |--- value: [11.00]
# |   |--- higher_yes >  0.50
# |   |   |--- age <= 19.50
# |   |   |   |--- goout <= 3.50
# |   |   |   |   |--- Medu <= 3.50
# |   |   |   |   |   |--- value: [8.17]
# |   |   |   |   |--- Medu >  3.50
# |   |   |   |   |   |--- value: [4.00]
# |   |   |   |--- goout >  3.50
# |   |   |   |   |--- Medu <= 3.50
# |   |   |   |   |   |--- value: [8.96]
# |   |   |   |   |--- Medu >  3.50
# |   |   |   |   |   |--- value: [11.67]
# |   |   |--- age >  19.50
# |   |   |   |--- romantic_yes <= 0.50
# |   |   |   |   |--- Medu <= 3.50
# |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |--- Medu >  3.50
# |   |   |   |   |   |--- value: [12.00]
# |   |   |   |--- romantic_yes >  0.50
# |   |   |   |   |--- value: [10.00]

# %% [markdown]
# ## Layers 2-14

# %% [markdown]
# $$
# R_\alpha(T) = R(T) + \alpha |T|
# $$

# %%
def compute_regularized_risk(model, X_test, y_test, alpha):
    mse = mean_squared_error(y_test, model.predict(X_test))
    n_leaves = model.get_n_leaves()  # Number of leaves
    return mse + alpha * n_leaves

# %% [markdown]
# ## Math

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error


depths = range(2, 15)  # Tree depths from 3 to 8
alpha = 0.1  # Regularization parameter

# Store results
results = []

for depth in depths:
    model = DecisionTreeRegressor(max_depth=depth, random_state=42)
    model.fit(X_train_math_selected, y_train_math)
    
    # Compute metrics
    mse = mean_squared_error(y_test_math, model.predict(X_test_math_selected))
    r2 = model.score(X_test_math_selected, y_test_math)
    regularized_risk = compute_regularized_risk(model, X_test_math_selected, y_test_math, alpha)
    
    
    results.append({"Depth": depth, "MSE": mse, "R²": r2, "Regularized Risk": regularized_risk})

import pandas as pd
results_df = pd.DataFrame(results)

# Display 
print(results_df)
# Out:
#     Depth        MSE        R²  Regularized Risk
# 0       2  18.771788  0.084528         19.171788
# 1       3  18.687764  0.088626         19.487764
# 2       4  20.376547  0.006267         21.776547
# 3       5  23.877990 -0.164493         26.477990
# 4       6  26.989241 -0.316224         31.189241
# 5       7  29.298962 -0.428866         35.398962
# 6       8  29.368281 -0.432246         37.768281
# 7       9  30.509985 -0.487926         41.009985
# 8      10  29.036852 -0.416083         41.536852
# 9      11  31.133215 -0.518320         45.633215
# 10     12  26.162357 -0.275898         42.462357
# 11     13  29.862429 -0.456345         48.162429
# 12     14  30.538444 -0.489313         50.338444

# %%
import matplotlib.pyplot as plt

# Plot the results
plt.figure(figsize=(10, 6))

# Plot MSE
plt.plot(results_df['Depth'], results_df['MSE'], marker='o', label='Mean Squared Error (MSE)')

# Plot R² Score
plt.plot(results_df['Depth'], results_df['R²'], marker='o', label='R² Score')

# Plot Regularized Risk
plt.plot(results_df['Depth'], results_df['Regularized Risk'], marker='o', label='Regularized Risk')

# Add labels, title, and legend
plt.title('Decision Tree Performance vs Depth')
plt.xlabel('Tree Depth')
plt.ylabel('Metrics')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error


depths = range(2, 15)  # Tree depths from 3 to 8
alpha = 0.1  # Regularization parameter

# Store results
results = []

for depth in depths:
    model = DecisionTreeRegressor(max_depth=depth, random_state=42)
    model.fit(X_train_por_selected, y_train_por)
    
    # Compute metrics
    mse = mean_squared_error(y_test_por, model.predict(X_test_por_selected))
    r2 = model.score(X_test_por_selected, y_test_por)
    regularized_risk = compute_regularized_risk(model, X_test_por_selected, y_test_por, alpha)
    
    
    results.append({"Depth": depth, "MSE": mse, "R²": r2, "Regularized Risk": regularized_risk})

import pandas as pd
results_df = pd.DataFrame(results)

# Display 
print(results_df)
# Out:
#     Depth        MSE        R²  Regularized Risk
# 0       2   8.172335  0.161959          8.572335
# 1       3   8.442874  0.134217          9.242874
# 2       4   8.764858  0.101198         10.364858
# 3       5   8.595407  0.118575         11.495407
# 4       6   9.046504  0.072317         13.946504
# 5       7   8.770593  0.100610         15.670593
# 6       8   9.315794  0.044702         18.815794
# 7       9   9.248810  0.051571         22.248810
# 8      10   9.050844  0.071872         26.350844
# 9      11   8.589566  0.119174         30.889566
# 10     12   9.859933 -0.011097         37.659933
# 11     13  12.450391 -0.276738         45.350391
# 12     14  13.164795 -0.349998         50.164795

# %%
import matplotlib.pyplot as plt

# Plot the results
plt.figure(figsize=(10, 6))

# Plot MSE
plt.plot(results_df['Depth'], results_df['MSE'], marker='o', label='Mean Squared Error (MSE)')

# Plot R² Score
plt.plot(results_df['Depth'], results_df['R²'], marker='o', label='R² Score')

# Plot Regularized Risk
plt.plot(results_df['Depth'], results_df['Regularized Risk'], marker='o', label='Regularized Risk')

# Add labels, title, and legend
plt.title('Decision Tree Performance vs Depth')
plt.xlabel('Tree Depth')
plt.ylabel('Metrics')
plt.legend()
plt.grid(True)
plt.show()
